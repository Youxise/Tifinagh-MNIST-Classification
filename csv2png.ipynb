# %%
import csv
from PIL import Image
import numpy as np
import os

last_digit_Name =  None

#your path to target folder to save images. Note: Path should have 33 empty folder with name as Alphabet_list
image_Folder_Path = "img" 


## uncomment according to the version you want 
#csv_File_Path = "Latin-version.csv"
csv_File_Path = "Tifinagh-version.csv" 

#Alphabet_list = ["A","Ԑ","B","C","Č","D","Ḍ","E","F","G","Ǧ","H","Ḥ","I","J","K","L","M","N","Q","Γ","R","Ṛ","S","Ṣ","T","Ṭ",
#                 "TT","U","W","X","Y","Z","Ẓ"]

Alphabet_list = ["ⴰ","ⴱ","ⵛ","ⴷ","ⴹ","ⵄ","ⴼ","ⴳ","ⵖ","ⴳⵯ","ⵀ","ⵃ","ⵊ","ⴽ","ⴽⵯ","ⵍ","ⵎ","ⵏ","ⵇ","ⵔ","ⵕ","ⵙ","ⵚ","ⵜ","ⵟ",
                "ⵡ","ⵅ","ⵢ","ⵣ","ⵥ","ⴻ","ⵉ","ⵓ"]

for alphabet in Alphabet_list:
    path = image_Folder_Path + '\\' + alphabet
    if not os.path.exists(path):
        os.makedirs(path)

with open(csv_File_Path, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='|')
    count = 0
    for row in reader:
        digit_Name = row.pop(0)
        image_array = np.asarray(row)
        image_array = image_array.reshape(28, 28)
        new_image = Image.fromarray(image_array.astype('uint8'))

        if last_digit_Name != str(Alphabet_list[(int)(digit_Name)]):
            last_digit_Name = str(Alphabet_list[(int)(digit_Name)])
            count = 0
            print ("")
            print ("Prcessing Alphabet - " + str (last_digit_Name))
        
        image_Path = image_Folder_Path + '\\' + last_digit_Name + '\\' + str(last_digit_Name) + '-' + str(count) + '.png'
        new_image.save(image_Path)
        count = count + 1

        if count % 1000 == 0:
            print ("Images processed: " + str(count))
# Out:
# Prcessing Alphabet - ⴰ
#
# Prcessing Alphabet - ⴱ
#
# Prcessing Alphabet - ⵛ
#
# Prcessing Alphabet - ⴷ
#
# Prcessing Alphabet - ⴹ
#
# Prcessing Alphabet - ⵄ
#
# Prcessing Alphabet - ⴼ
#
# Prcessing Alphabet - ⴳ
#
# Prcessing Alphabet - ⵖ
#
# Prcessing Alphabet - ⴳⵯ
#
# Prcessing Alphabet - ⵀ
#
# Prcessing Alphabet - ⵃ
#
# Prcessing Alphabet - ⵊ
#
# Prcessing Alphabet - ⴽ
#
# Prcessing Alphabet - ⴽⵯ
#
# Prcessing Alphabet - ⵍ
#
# Prcessing Alphabet - ⵎ
#
# Prcessing Alphabet - ⵏ
#
# Prcessing Alphabet - ⵇ
#
# Prcessing Alphabet - ⵔ
#
# Prcessing Alphabet - ⵕ
#
# Prcessing Alphabet - ⵙ
#
# Prcessing Alphabet - ⵚ
#
# Prcessing Alphabet - ⵜ
#
# Prcessing Alphabet - ⵟ
#
# Prcessing Alphabet - ⵡ
#
# Prcessing Alphabet - ⵅ
#
# Prcessing Alphabet - ⵢ
#
# Prcessing Alphabet - ⵣ
#
# Prcessing Alphabet - ⵥ
#
# Prcessing Alphabet - ⴻ
#
# Prcessing Alphabet - ⵉ
#
# Prcessing Alphabet - ⵓ
